# %% [markdown]
# # Generating SQL for SQLite using Google Gemini, ChromaDB
# This notebook runs through the process of using the `vanna` Python package to generate SQL using AI (RAG + LLMs) including connecting to a database and training. If you're not ready to train on your own database, you can still try it using a sample [SQLite database](app.md).

# %% [markdown]
# <h3 class="mb-5 text-lg font-medium text-gray-900 dark:text-white">Which LLM do you want to use?</h3>
# <ul class="grid w-full gap-6 md:grid-cols-2">
#
#   <li>
#     <a href="../sqlite-openai-vanna-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">OpenAI via Vanna.AI (Recommended)</div>
#         <small class="w-full">Use Vanna.AI for free to generate your queries</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-openai-standard-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">OpenAI</div>
#         <small class="w-full">Use OpenAI with your own API key</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-openai-azure-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Azure OpenAI</div>
#         <small class="w-full">If you have OpenAI models deployed on Azure</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-anthropic-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Anthropic</div>
#         <small class="w-full">Use Anthropics Claude with your Anthropic API Key</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-ollama-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Ollama</div>
#         <small class="w-full">Use Ollama locally for free. Requires additional setup.</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <span class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border bg-white p-5 border-blue-600 text-blue-600 dark:bg-gray-800 dark:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold"><span class="hidden">[Selected]</span> Google Gemini</div>
#         <small class="w-full">Use Google Gemini with your Gemini or Vertex API Key</small>
#       </div>
#     </span>
#   </li>
#
#   <li>
#     <a href="../sqlite-mistral-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Mistral via Mistral API</div>
#         <small class="w-full">If you have a Mistral API key</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-other-llm-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Other LLM</div>
#         <small class="w-full">If you have a different LLM model</small>
#       </div>
#     </a>
#   </li>
#
# </ul>

# %% [markdown]
# <h3 class="mb-5 text-lg font-medium text-gray-900 dark:text-white">Where do you want to store the 'training' data?</h3>
# <ul class="grid w-full gap-6 md:grid-cols-2">
#
#   <li>
#     <a href="../sqlite-gemini-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Vanna Hosted Vector DB (Recommended)</div>
#         <small class="w-full">Use Vanna.AIs hosted vector database (pgvector) for free. This is usable across machines with no additional setup.</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <span class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border bg-white p-5 border-blue-600 text-blue-600 dark:bg-gray-800 dark:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold"><span class="hidden">[Selected]</span> ChromaDB</div>
#         <small class="w-full">Use ChromaDBs open-source vector database for free locally. No additional setup is necessary -- all database files will be created and stored locally.</small>
#       </div>
#     </span>
#   </li>
#
#   <li>
#     <a href="../sqlite-gemini-qdrant/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Qdrant</div>
#         <small class="w-full">Use Qdrants open-source vector database</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-gemini-marqo/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Marqo</div>
#         <small class="w-full">Use Marqo locally for free. Requires additional setup. Or use their hosted option.</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-gemini-other-vectordb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Other VectorDB</div>
#         <small class="w-full">Use any other vector database. Requires additional setup.</small>
#       </div>
#     </a>
#   </li>
#
# </ul>

# %% [markdown]
# ## Setup

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (25.1.1)

# %%
# !pip install vanna[chromadb,gemini]
# Out:
# Requirement already satisfied: vanna[chromadb,gemini] in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (0.7.9)
# Requirement already satisfied: requests in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,gemini]) (2.32.4)
# Requirement already satisfied: tabulate in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,gemini]) (0.9.0)
# Requirement already satisfied: plotly in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,gemini]) (6.2.0)
# Requirement already satisfied: pandas in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,gemini]) (2.3.1)
# Requirement already satisfied: sqlparse in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,gemini]) (0.5.3)
# Requirement already satisfied: kaleido in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,gemini]) (1.0.0)
# Requirement already satisfied: flask in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,gemini]) (3.1.1)
# Requirement already satisfied: flask-sock in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,gemini]) (0.7.0)
# Requirement already satisfied: flasgger in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,gemini]) (0.9.7.1)
# Requirement already satisfied: sqlalchemy in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,gemini]) (2.0.41)
# Requirement already satisfied: chromadb<1.0.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,gemini]) (0.6.3)
# Requirement already satisfied: google-generativeai in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,gemini]) (0.8.5)
# Requirement already satisfied: build>=1.0.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (2.11.7)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.116.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,gemini]) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (2.2.6)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (6.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (4.14.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (1.35.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (1.35.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.56b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (1.35.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (9.1.2)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (3.11.0)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,gemini]) (14.0.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from build>=1.0.3->chromadb<1.0.0->vanna[chromadb,gemini]) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb<1.0.0->vanna[chromadb,gemini]) (1.2.0)
# Requirement already satisfied: colorama in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from build>=1.0.3->chromadb<1.0.0->vanna[chromadb,gemini]) (0.4.6)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb<1.0.0->vanna[chromadb,gemini]) (8.7.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb<1.0.0->vanna[chromadb,gemini]) (2.2.1)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,gemini]) (0.47.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb<1.0.0->vanna[chromadb,gemini]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb<1.0.0->vanna[chromadb,gemini]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb<1.0.0->vanna[chromadb,gemini]) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from starlette<0.48.0,>=0.40.0->fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,gemini]) (4.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,gemini]) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,gemini]) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,gemini]) (1.3.1)
# Requirement already satisfied: certifi in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb<1.0.0->vanna[chromadb,gemini]) (3.23.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (5.29.5)
# Requirement already satisfied: sympy in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (1.14.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.35.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.35.0)
# Requirement already satisfied: opentelemetry-proto==1.35.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.35.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.56b0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.56b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.56b0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.56b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.56b0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.56b0)
# Requirement already satisfied: opentelemetry-util-http==0.56b0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.56b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation==0.56b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-asgi==0.56b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,gemini]) (3.9.1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from requests->vanna[chromadb,gemini]) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->chromadb<1.0.0->vanna[chromadb,gemini]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->chromadb<1.0.0->vanna[chromadb,gemini]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<1.0.0->vanna[chromadb,gemini]) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from tokenizers>=0.13.2->chromadb<1.0.0->vanna[chromadb,gemini]) (0.33.4)
# Requirement already satisfied: filelock in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<1.0.0->vanna[chromadb,gemini]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<1.0.0->vanna[chromadb,gemini]) (2025.7.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb<1.0.0->vanna[chromadb,gemini]) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb<1.0.0->vanna[chromadb,gemini]) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,gemini]) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,gemini]) (1.1.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,gemini]) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,gemini]) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (3.5.4)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flasgger->vanna[chromadb,gemini]) (4.25.0)
# Requirement already satisfied: mistune in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flasgger->vanna[chromadb,gemini]) (3.1.3)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[chromadb,gemini]) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[chromadb,gemini]) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[chromadb,gemini]) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[chromadb,gemini]) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[chromadb,gemini]) (3.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,gemini]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,gemini]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,gemini]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,gemini]) (0.26.0)
# Requirement already satisfied: simple-websocket>=0.5.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask-sock->vanna[chromadb,gemini]) (1.1.0)
# Requirement already satisfied: wsproto in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from simple-websocket>=0.5.1->flask-sock->vanna[chromadb,gemini]) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-generativeai->vanna[chromadb,gemini]) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-generativeai->vanna[chromadb,gemini]) (2.25.1)
# Requirement already satisfied: google-api-python-client in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-generativeai->vanna[chromadb,gemini]) (2.176.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai->vanna[chromadb,gemini]) (1.26.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai->vanna[chromadb,gemini]) (1.71.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-api-python-client->google-generativeai->vanna[chromadb,gemini]) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-api-python-client->google-generativeai->vanna[chromadb,gemini]) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-api-python-client->google-generativeai->vanna[chromadb,gemini]) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai->vanna[chromadb,gemini]) (3.2.3)
# Requirement already satisfied: choreographer>=1.0.5 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kaleido->vanna[chromadb,gemini]) (1.0.9)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kaleido->vanna[chromadb,gemini]) (1.1.0)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from choreographer>=1.0.5->kaleido->vanna[chromadb,gemini]) (3.20.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pandas->vanna[chromadb,gemini]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pandas->vanna[chromadb,gemini]) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from plotly->vanna[chromadb,gemini]) (1.48.0)
# Requirement already satisfied: greenlet>=1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy->vanna[chromadb,gemini]) (3.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,gemini]) (1.3.0)

# %%
# !pip install vanna[gemini]
# Out:
# Requirement already satisfied: vanna[gemini] in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (0.7.9)
# Requirement already satisfied: requests in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[gemini]) (2.32.4)
# Requirement already satisfied: tabulate in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[gemini]) (0.9.0)
# Requirement already satisfied: plotly in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[gemini]) (6.2.0)
# Requirement already satisfied: pandas in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[gemini]) (2.3.1)
# Requirement already satisfied: sqlparse in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[gemini]) (0.5.3)
# Requirement already satisfied: kaleido in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[gemini]) (1.0.0)
# Requirement already satisfied: flask in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[gemini]) (3.1.1)
# Requirement already satisfied: flask-sock in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[gemini]) (0.7.0)
# Requirement already satisfied: flasgger in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[gemini]) (0.9.7.1)
# Requirement already satisfied: sqlalchemy in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[gemini]) (2.0.41)
# Requirement already satisfied: google-generativeai in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[gemini]) (0.8.5)
# Requirement already satisfied: PyYAML>=3.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flasgger->vanna[gemini]) (6.0.2)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flasgger->vanna[gemini]) (4.25.0)
# Requirement already satisfied: mistune in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flasgger->vanna[gemini]) (3.1.3)
# Requirement already satisfied: six>=1.10.0 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from flasgger->vanna[gemini]) (1.17.0)
# Requirement already satisfied: packaging in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from flasgger->vanna[gemini]) (25.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[gemini]) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[gemini]) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[gemini]) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[gemini]) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[gemini]) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[gemini]) (3.1.3)
# Requirement already satisfied: colorama in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from click>=8.1.3->flask->vanna[gemini]) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[gemini]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[gemini]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[gemini]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[gemini]) (0.26.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from referencing>=0.28.4->jsonschema>=3.0.1->flasgger->vanna[gemini]) (4.14.1)
# Requirement already satisfied: simple-websocket>=0.5.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask-sock->vanna[gemini]) (1.1.0)
# Requirement already satisfied: wsproto in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from simple-websocket>=0.5.1->flask-sock->vanna[gemini]) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-generativeai->vanna[gemini]) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-generativeai->vanna[gemini]) (2.25.1)
# Requirement already satisfied: google-api-python-client in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-generativeai->vanna[gemini]) (2.176.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-generativeai->vanna[gemini]) (2.40.3)
# Requirement already satisfied: protobuf in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-generativeai->vanna[gemini]) (5.29.5)
# Requirement already satisfied: pydantic in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-generativeai->vanna[gemini]) (2.11.7)
# Requirement already satisfied: tqdm in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-generativeai->vanna[gemini]) (4.67.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai->vanna[gemini]) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-api-core->google-generativeai->vanna[gemini]) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai->vanna[gemini]) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai->vanna[gemini]) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=2.15.0->google-generativeai->vanna[gemini]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=2.15.0->google-generativeai->vanna[gemini]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=2.15.0->google-generativeai->vanna[gemini]) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from requests->vanna[gemini]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from requests->vanna[gemini]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from requests->vanna[gemini]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from requests->vanna[gemini]) (2025.7.14)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai->vanna[gemini]) (0.6.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-api-python-client->google-generativeai->vanna[gemini]) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-api-python-client->google-generativeai->vanna[gemini]) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-api-python-client->google-generativeai->vanna[gemini]) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai->vanna[gemini]) (3.2.3)
# Requirement already satisfied: choreographer>=1.0.5 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kaleido->vanna[gemini]) (1.0.9)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kaleido->vanna[gemini]) (1.1.0)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kaleido->vanna[gemini]) (3.11.0)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from choreographer>=1.0.5->kaleido->vanna[gemini]) (3.20.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pandas->vanna[gemini]) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from pandas->vanna[gemini]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pandas->vanna[gemini]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pandas->vanna[gemini]) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from plotly->vanna[gemini]) (1.48.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pydantic->google-generativeai->vanna[gemini]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pydantic->google-generativeai->vanna[gemini]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pydantic->google-generativeai->vanna[gemini]) (0.4.1)
# Requirement already satisfied: greenlet>=1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy->vanna[gemini]) (3.2.3)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from wsproto->simple-websocket>=0.5.1->flask-sock->vanna[gemini]) (0.16.0)

# %%
# %pip install vanna[chromadb,openai]
# Out:
# Requirement already satisfied: vanna[chromadb,openai] in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (0.7.9)
# Requirement already satisfied: requests in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,openai]) (2.32.4)
# Requirement already satisfied: tabulate in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,openai]) (0.9.0)
# Requirement already satisfied: plotly in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,openai]) (6.2.0)
# Requirement already satisfied: pandas in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,openai]) (2.3.1)
# Requirement already satisfied: sqlparse in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,openai]) (0.5.3)
# Requirement already satisfied: kaleido in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,openai]) (1.0.0)
# Requirement already satisfied: flask in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,openai]) (3.1.1)
# Requirement already satisfied: flask-sock in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,openai]) (0.7.0)
# Requirement already satisfied: flasgger in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,openai]) (0.9.7.1)
# Requirement already satisfied: sqlalchemy in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,openai]) (2.0.41)
# Requirement already satisfied: chromadb<1.0.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from vanna[chromadb,openai]) (0.6.3)
# Collecting openai (from vanna[chromadb,openai])
#   Downloading openai-1.97.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: build>=1.0.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (2.11.7)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (0.116.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,openai]) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (2.2.6)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (6.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (4.14.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (1.35.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (1.35.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (0.56b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (1.35.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (9.1.2)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (3.11.0)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from chromadb<1.0.0->vanna[chromadb,openai]) (14.0.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from build>=1.0.3->chromadb<1.0.0->vanna[chromadb,openai]) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb<1.0.0->vanna[chromadb,openai]) (1.2.0)
# Requirement already satisfied: colorama in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from build>=1.0.3->chromadb<1.0.0->vanna[chromadb,openai]) (0.4.6)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb<1.0.0->vanna[chromadb,openai]) (8.7.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb<1.0.0->vanna[chromadb,openai]) (2.2.1)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,openai]) (0.47.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb<1.0.0->vanna[chromadb,openai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb<1.0.0->vanna[chromadb,openai]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.9->chromadb<1.0.0->vanna[chromadb,openai]) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from starlette<0.48.0,>=0.40.0->fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,openai]) (4.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,openai]) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,openai]) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi>=0.95.2->chromadb<1.0.0->vanna[chromadb,openai]) (1.3.1)
# Requirement already satisfied: certifi in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb<1.0.0->vanna[chromadb,openai]) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb<1.0.0->vanna[chromadb,openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<1.0.0->vanna[chromadb,openai]) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb<1.0.0->vanna[chromadb,openai]) (3.23.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,openai]) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,openai]) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,openai]) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,openai]) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,openai]) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,openai]) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,openai]) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,openai]) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,openai]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,openai]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,openai]) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<1.0.0->vanna[chromadb,openai]) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,openai]) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,openai]) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,openai]) (5.29.5)
# Requirement already satisfied: sympy in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,openai]) (1.14.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<1.0.0->vanna[chromadb,openai]) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.35.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<1.0.0->vanna[chromadb,openai]) (1.35.0)
# Requirement already satisfied: opentelemetry-proto==1.35.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<1.0.0->vanna[chromadb,openai]) (1.35.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.56b0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<1.0.0->vanna[chromadb,openai]) (0.56b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.56b0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,openai]) (0.56b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.56b0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,openai]) (0.56b0)
# Requirement already satisfied: opentelemetry-util-http==0.56b0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,openai]) (0.56b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation==0.56b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,openai]) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-asgi==0.56b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<1.0.0->vanna[chromadb,openai]) (3.9.1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb<1.0.0->vanna[chromadb,openai]) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb<1.0.0->vanna[chromadb,openai]) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from requests->vanna[chromadb,openai]) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->chromadb<1.0.0->vanna[chromadb,openai]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tabdu\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->chromadb<1.0.0->vanna[chromadb,openai]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<1.0.0->vanna[chromadb,openai]) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from tokenizers>=0.13.2->chromadb<1.0.0->vanna[chromadb,openai]) (0.33.4)
# Requirement already satisfied: filelock in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<1.0.0->vanna[chromadb,openai]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<1.0.0->vanna[chromadb,openai]) (2025.7.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb<1.0.0->vanna[chromadb,openai]) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb<1.0.0->vanna[chromadb,openai]) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,openai]) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,openai]) (1.1.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,openai]) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<1.0.0->vanna[chromadb,openai]) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,openai]) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,openai]) (3.5.4)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flasgger->vanna[chromadb,openai]) (4.25.0)
# Requirement already satisfied: mistune in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flasgger->vanna[chromadb,openai]) (3.1.3)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[chromadb,openai]) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[chromadb,openai]) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[chromadb,openai]) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[chromadb,openai]) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask->vanna[chromadb,openai]) (3.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,openai]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,openai]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,openai]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,openai]) (0.26.0)
# Requirement already satisfied: simple-websocket>=0.5.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from flask-sock->vanna[chromadb,openai]) (1.1.0)
# Requirement already satisfied: wsproto in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from simple-websocket>=0.5.1->flask-sock->vanna[chromadb,openai]) (1.2.0)
# Requirement already satisfied: choreographer>=1.0.5 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kaleido->vanna[chromadb,openai]) (1.0.9)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from kaleido->vanna[chromadb,openai]) (1.1.0)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from choreographer>=1.0.5->kaleido->vanna[chromadb,openai]) (3.20.1)
# Collecting jiter<1,>=0.4.0 (from openai->vanna[chromadb,openai])
#   Using cached jiter-0.10.0-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pandas->vanna[chromadb,openai]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from pandas->vanna[chromadb,openai]) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from plotly->vanna[chromadb,openai]) (1.48.0)
# Requirement already satisfied: greenlet>=1 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy->vanna[chromadb,openai]) (3.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tabdu\appdata\local\programs\python\python310\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<1.0.0->vanna[chromadb,openai]) (1.3.0)
# Downloading openai-1.97.0-py3-none-any.whl (764 kB)
#    ---------------------------------------- 0.0/765.0 kB ? eta -:--:--
#    --------------------------------------- 765.0/765.0 kB 10.7 MB/s eta 0:00:00
# Using cached jiter-0.10.0-cp310-cp310-win_amd64.whl (207 kB)
# Installing collected packages: jiter, openai
#
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    ---------------------------------------- 2/2 [openai]
#
# Successfully installed jiter-0.10.0 openai-1.97.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from vanna.chromadb import ChromaDB_VectorStore
from vanna.google import GoogleGeminiChat

# %%
import os 
from dotenv import load_dotenv
load_dotenv()


OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    raise ValueError("Please set the OPENAI_API_KEY environment variable.")

# %%
from vanna.openai import OpenAI_Chat


class MyVanna(ChromaDB_VectorStore, OpenAI_Chat):
    def __init__(self, config=None):
        ChromaDB_VectorStore.__init__(self, config=config)
        OpenAI_Chat.__init__(self, config=config)

vn = MyVanna(config={'api_key': OPENAI_API_KEY, 'model': 'gpt-4o'})
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given

# %% [markdown]
# <h3 class="mb-5 text-lg font-medium text-gray-900 dark:text-white">Which database do you want to query?</h3>
# <ul class="grid w-full gap-6 md:grid-cols-2">
#
#   <li>
#     <a href="../postgres-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Postgres</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mssql-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Microsoft SQL Server</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mysql-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">MySQL</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../duckdb-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">DuckDB</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../snowflake-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Snowflake</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../bigquery-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">BigQuery</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <span class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border bg-white p-5 border-blue-600 text-blue-600 dark:bg-gray-800 dark:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold"><span class="hidden">[Selected]</span> SQLite</div>
#         <small class="w-full"></small>
#       </div>
#     </span>
#   </li>
#
#   <li>
#     <a href="../oracle-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Oracle</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../other-database-gemini-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Other Database</div>
#         <small class="w-full">Use Vanna to generate queries for any SQL database</small>
#       </div>
#     </a>
#   </li>
#
# </ul>

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/simulated_msmeloans_data.csv')

# %%
df.head()
# Out:
#    Gender   State         Sector    CreditID     CusID           FullNames  \
# 0    Male   Enugu         Health  CAM-100000  CUS-1000          Paul Bates
# 1  Female  Rivers         Health  CAM-100001  CUS-1001  Gail Carpenter DDS
# 2    Male  Rivers         Health  CAM-100002  CUS-1002      Jason Gonzalez
# 3    Male   Enugu  Manufacturing  CAM-100003  CUS-1003        Gina Roberts
# 4    Male   Lagos  Manufacturing  CAM-100004  CUS-1004     Jennifer Franco
#
#                   CompanyName   BirthDate  \
# 0    Brown, Ritter and Gaines  1998-11-16
# 1                Barrera-Bell  2004-10-23
# 2              Callahan-Adams  1999-10-05
# 3            Greene-Rodriguez  1979-09-14
# 4  Barrera, Prince and Morrow  2004-01-15
#
#                                             Address                 TelNo  \
# 0                  PSC 1418, Box 0373\nAPO AP 11453     (296)718-1504x183
# 1             408 Harrell Glens\nDebraton, NJ 31431  001-652-807-5595x596
# 2    219 Frank Trail Suite 898\nCorymouth, AR 34375     700-620-3219x4404
# 3    78658 Tara Ranch\nNorth Shannonmouth, NJ 13667  +1-064-283-3934x8686
# 4  455 Jo Lane Suite 372\nNorth Lauraview, LA 01108   +1-672-643-4320x065
#
#    ... NumberOfEmployees  Age age_group_id  ES_Rating  \
# 0  ...                67   21        Youth          A
# 1  ...                87   10        Adult          B
# 2  ...                29   25        Adult          C
# 3  ...                34   12        Adult          B
# 4  ...                97   12        Adult          B
#
#   green_energy/energy_efficiency  TenorInDays MaturityDate  \
# 0                           True          210   2024-04-16
# 1                          False          840   2026-02-08
# 2                           True          720   2025-08-20
# 3                           True         1080   2026-06-19
# 4                          False         1680   2028-04-09
#
#   InterestRepayStartDate PrincipalRepayStartDate   DateAdded
# 0             2023-10-19              2023-11-18  2024-01-01
# 1             2023-11-21              2023-12-21  2024-01-01
# 2             2023-09-30              2023-10-30  2024-01-01
# 3             2023-08-04              2023-09-03  2024-01-01
# 4             2023-10-03              2023-11-02  2024-01-01
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['Gender', 'State', 'Sector', 'CreditID', 'CusID', 'FullNames',
#        'CompanyName', 'BirthDate', 'Address', 'TelNo', 'EmailAddr',
#        'AmountGranted', 'EffectiveDate', 'Tenor', 'TenorType', 'Rate',
#        'ScheduleType', 'InterestRepayFreq', 'PrincipalRepayFreq',
#        'NatureOfBusiness', 'FirstTimeAccessToCredit', 'StartUp',
#        'MSMEAnnualTurnover', 'NumberOfEmployees', 'Age', 'age_group_id',
#        'ES_Rating', 'green_energy/energy_efficiency', 'TenorInDays',
#        'MaturityDate', 'InterestRepayStartDate', 'PrincipalRepayStartDate',
#        'DateAdded'],
#       dtype='object')

# %%
import sqlite3

conn = sqlite3.connect('dbn-poc-database.db')

df.to_sql('msmeloans', conn, if_exists='replace', index=False)
# Out:
# 500

# %%
vn.connect_to_sqlite('dbn-poc-database.db')

# %% [markdown]
# ## Training
# You only need to train once. Do not train again unless you want to add more training data.

# %%
df_ddl = vn.run_sql("SELECT type, sql FROM sqlite_master WHERE sql is not null")

for ddl in df_ddl['sql'].to_list():
  vn.train(ddl=ddl)
# Out:
# Insert of existing embedding ID: 0f29106f-f45f-5b04-bfa1-af6bcf0c4554-ddl
# Add of existing embedding ID: 0f29106f-f45f-5b04-bfa1-af6bcf0c4554-ddl
# Adding ddl: CREATE TABLE "msmeloans" (
# "Gender" TEXT,
#   "State" TEXT,
#   "Sector" TEXT,
#   "CreditID" TEXT,
#   "CusID" TEXT,
#   "FullNames" TEXT,
#   "CompanyName" TEXT,
#   "BirthDate" TEXT,
#   "Address" TEXT,
#   "TelNo" TEXT,
#   "EmailAddr" TEXT,
#   "AmountGranted" INTEGER,
#   "EffectiveDate" TEXT,
#   "Tenor" INTEGER,
#   "TenorType" TEXT,
#   "Rate" REAL,
#   "ScheduleType" TEXT,
#   "InterestRepayFreq" TEXT,
#   "PrincipalRepayFreq" TEXT,
#   "NatureOfBusiness" TEXT,
#   "FirstTimeAccessToCredit" INTEGER,
#   "StartUp" INTEGER,
#   "MSMEAnnualTurnover" INTEGER,
#   "NumberOfEmployees" INTEGER,
#   "Age" INTEGER,
#   "age_group_id" TEXT,
#   "ES_Rating" TEXT,
#   "green_energy/energy_efficiency" INTEGER,
#   "TenorInDays" INTEGER,
#   "MaturityDate" TEXT,
#   "InterestRepayStartDate" TEXT,
#   "PrincipalRepayStartDate" TEXT,
#   "DateAdded" TEXT
# )

# %%
vn.train(
    question="What is the average loan size by sector?", 
    sql="""
    SELECT 
        Sector,
        AVG(AmountGranted) AS average_loan_size
    FROM 
        msmeloans
    GROUP BY 
        Sector
    ORDER BY 
        average_loan_size DESC;
    """
)
# Out:
# Insert of existing embedding ID: b8e0129e-5d15-52cd-8fef-dff8b4d098e7-sql
# Add of existing embedding ID: b8e0129e-5d15-52cd-8fef-dff8b4d098e7-sql
# 'b8e0129e-5d15-52cd-8fef-dff8b4d098e7-sql'

# %%
vn.train(
    question="Compare disbursements across regions YTD?", 
    sql="""
   SELECT 
        State AS region,
        SUM(AmountGranted) AS total_disbursed_ytd
    FROM 
        msmeloans
    WHERE 
        EXTRACT(YEAR FROM EffectiveDate) = EXTRACT(YEAR FROM CURRENT_DATE)
        AND EffectiveDate <= CURRENT_DATE
    GROUP BY 
        State
    ORDER BY 
        total_disbursed_ytd DESC;
    """
)
# Out:
# '72976ea9-9f79-54fe-887a-587ed15f6a9d-sql'

# %%
# vn.train(
#     question="Which partners have highest approval rates?", 
#     sql="""
#    SELECT 
#         CusID AS PartnerID,
#         COUNT(CASE WHEN Status = 'Approved' THEN 1 END) * 1.0 / COUNT(*) AS approval_rate,
#         COUNT(*) AS total_applications
#     FROM 
#         msmeloans
#     GROUP BY 
#         CusID
#     ORDER BY 
#         approval_rate DESC;
#     """
# )
# Out:
# 'b967c055-c8df-58e5-b657-dfea8f01eb08-sql'

# %%
vn.train(
    question="Show quality score of top 10 loan records", 
    sql="""
   SELECT 
        CreditID,
        CusID,
        CompanyName,
        AmountGranted,
        ES_Rating AS quality_score
    FROM 
        msmeloans
    WHERE 
        ES_Rating IS NOT NULL
    ORDER BY 
        ES_Rating DESC
    LIMIT 10;
    """
)
# Out:
# '1297fda0-7b7f-5925-be6a-ee37e34e9b23-sql'

# %%
# # The following are methods for adding training data. Make sure you modify the examples to match your database.

# # DDL statements are powerful because they specify table names, colume names, types, and potentially relationships
# vn.train(ddl="""
#     CREATE TABLE IF NOT EXISTS my-table (
#         id INT PRIMARY KEY,
#         name VARCHAR(100),
#         age INT
#     )
# """)

# # Sometimes you may want to add documentation about your business terminology or definitions.
# vn.train(documentation="Our business defines OTIF score as the percentage of orders that are delivered on time and in full")

# # You can also add SQL queries to your training data. This is useful if you have some queries already laying around. You can just copy and paste those from your editor to begin generating new SQL.
# vn.train(sql="SELECT * FROM my-table WHERE name = 'John Doe'")

# %%
# At any time you can inspect what training data the package is able to reference
training_data = vn.get_training_data()
training_data
# Out:
#                                          id  \
# 0  b8e0129e-5d15-52cd-8fef-dff8b4d098e7-sql
# 1  72976ea9-9f79-54fe-887a-587ed15f6a9d-sql
# 2  1297fda0-7b7f-5925-be6a-ee37e34e9b23-sql
# 0  0f29106f-f45f-5b04-bfa1-af6bcf0c4554-ddl
#
#                                     question  \
# 0   What is the average loan size by sector?
# 1  Compare disbursements across regions YTD?
# 2  Show quality score of top 10 loan records
# 0                                       None
#
#                                              content training_data_type
# 0  \n    SELECT \n        Sector,\n        AVG(Am...                sql
# 1  \n   SELECT \n        State AS region,\n      ...                sql
# 2  \n   SELECT \n        CreditID,\n        CusID...                sql
# 0  CREATE TABLE "msmeloans" (\n"Gender" TEXT,\n  ...                ddl

# %%
# # You can remove training data if there's obsolete/incorrect information.
vn.remove_training_data(id='b967c055-c8df-58e5-b657-dfea8f01eb08-sql')
# Out:
# Failed to send telemetry event CollectionDeleteEvent: capture() takes 1 positional argument but 3 were given
# True

# %% [markdown]
# ## Asking the AI
# Whenever you ask a new question, it will find the 10 most relevant pieces of training data and use it as part of the LLM prompt to generate the SQL.

# %%
vn.ask(question=...)
# Out:
# Expected document to be a str, got Ellipsis in query.
# (None, None, None)

# %% [markdown]
# ## Launch the User Interface
# ![vanna-flask](https://vanna.ai/blog/img/vanna-flask.gif)

# %%
from vanna.flask import VannaFlaskApp
app = VannaFlaskApp(vn)
app.run()
# Out:
# Your app is running at:
# http://localhost:8084
#  * Serving Flask app 'vanna.flask'
#  * Debug mode: on
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# Number of requested results 10 is greater than number of elements in index 4, updating n_results = 4
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# Number of requested results 10 is greater than number of elements in index 1, updating n_results = 1
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# Traceback (most recent call last):
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1536, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1514, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\vanna\flask\__init__.py", line 138, in decorated
#     return f(*args, user=user, **kwargs)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\vanna\flask\__init__.py", line 335, in generate_sql
#     sql = vn.generate_sql(question=question, allow_llm_to_see_data=self.allow_llm_to_see_data)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\vanna\base\base.py", line 136, in generate_sql
#     llm_response = self.submit_prompt(prompt, **kwargs)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\vanna\google\gemini_chat.py", line 68, in submit_prompt
#     response = self.chat_model.generate_content(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\generativeai\generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py", line 835, in generate_content
#     response = rpc(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\gapic_v1\method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_unary.py", line 294, in retry_wrapped_func
#     return retry_target(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_unary.py", line 156, in retry_target
#     next_sleep = _retry_error_helper(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_base.py", line 214, in _retry_error_helper
#     raise final_exc from source_exc
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_unary.py", line 147, in retry_target
#     result = target()
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\timeout.py", line 130, in func_with_timeout
#     return func(*args, **kwargs)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 57
# }
# ]
# Traceback (most recent call last):
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1536, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1514, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\vanna\flask\__init__.py", line 138, in decorated
#     return f(*args, user=user, **kwargs)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\vanna\flask\__init__.py", line 377, in generate_rewritten_question
#     rewritten_question = self.vn.generate_rewritten_question(last_question, new_question)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\vanna\base\base.py", line 301, in generate_rewritten_question
#     return self.submit_prompt(prompt=prompt, **kwargs)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\vanna\google\gemini_chat.py", line 68, in submit_prompt
#     response = self.chat_model.generate_content(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\generativeai\generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py", line 835, in generate_content
#     response = rpc(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\gapic_v1\method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_unary.py", line 294, in retry_wrapped_func
#     return retry_target(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_unary.py", line 156, in retry_target
#     next_sleep = _retry_error_helper(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_base.py", line 214, in _retry_error_helper
#     raise final_exc from source_exc
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_unary.py", line 147, in retry_target
#     result = target()
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\timeout.py", line 130, in func_with_timeout
#     return func(*args, **kwargs)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ]
# Number of requested results 10 is greater than number of elements in index 4, updating n_results = 4
# Number of requested results 10 is greater than number of elements in index 1, updating n_results = 1
# Traceback (most recent call last):
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1536, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1514, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\vanna\flask\__init__.py", line 138, in decorated
#     return f(*args, user=user, **kwargs)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\vanna\flask\__init__.py", line 335, in generate_sql
#     sql = vn.generate_sql(question=question, allow_llm_to_see_data=self.allow_llm_to_see_data)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\vanna\base\base.py", line 136, in generate_sql
#     llm_response = self.submit_prompt(prompt, **kwargs)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\vanna\google\gemini_chat.py", line 68, in submit_prompt
#     response = self.chat_model.generate_content(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\generativeai\generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py", line 835, in generate_content
#     response = rpc(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\gapic_v1\method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_unary.py", line 294, in retry_wrapped_func
#     return retry_target(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_unary.py", line 156, in retry_target
#     next_sleep = _retry_error_helper(
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_base.py", line 214, in _retry_error_helper
#     raise final_exc from source_exc
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_unary.py", line 147, in retry_target
#     result = target()
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\timeout.py", line 130, in func_with_timeout
#     return func(*args, **kwargs)
#   File "c:\Users\tabdu\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]

# %% [markdown]
# ## Next Steps
# Using Vanna via Jupyter notebooks is great for getting started but check out additional customizable interfaces like the
# - [Streamlit app](https://github.com/vanna-ai/vanna-streamlit)
# - [Flask app](https://github.com/vanna-ai/vanna-flask)
# - [Slackbot](https://github.com/vanna-ai/vanna-slack)
